# %%
import pandas as pd
from sklearn.metrics import classification_report, accuracy_score

# Load the dataset
df = pd.read_csv('NASI copy.csv')

# Get predictions and ground truth
predicted = df['category']
ground_truth = df['orig_category']

# Accuracy
accuracy = accuracy_score(ground_truth, predicted)
print(f"Accuracy: {accuracy:.2f}")

# Precision, Recall, and F1-Score
report = classification_report(ground_truth, predicted, target_names=['C1', 'C2', 'C3', 'C4', 'C5', 'C6'])
print(report)
# Out:
# Accuracy: 0.54
#               precision    recall  f1-score   support
#
#           C1       0.19      0.34      0.25        56
#           C2       0.92      0.27      0.42       582
#           C3       0.40      0.65      0.49       584
#           C4       0.71      0.58      0.64      1281
#           C5       0.49      0.66      0.56      1316
#           C6       0.61      0.24      0.35       323
#
#     accuracy                           0.54      4142
#    macro avg       0.55      0.46      0.45      4142
# weighted avg       0.61      0.54      0.54      4142

# %% [markdown]
# # Confusion Matrix

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('NASI copy.csv')

# Extract predicted and true categories
predicted = df['category']
ground_truth = df['orig_category']

# %%
# Define category labels
categories = ['C1', 'C2', 'C3', 'C4', 'C5', 'C6']

# Generate confusion matrix
cm = confusion_matrix(ground_truth, predicted, labels=categories)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=categories)
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix')
plt.show()

# %%
import numpy as np

# Normalize confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Display normalized confusion matrix
disp_normalized = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=categories)
disp_normalized.plot(cmap='Blues', values_format='.2f')
plt.title('Normalized Confusion Matrix')
plt.show()
